# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# import the datetime module from the datetime library
from datetime import datetime


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
latitude_longtitude = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
latitude_range = (-90, 90)
longtitude_range = (-180, 180)

# Create a set of random lat and lng combinations
latitude = np.random.uniform(latitude_range[0], latitude_range[1], size=1500)
longtitude = np.random.uniform(longtitude_range[0], longtitude_range[1], size=1500)
latitude_longtitude = zip(latitude, longtitude)

# Identify nearest city for each lat, lng combination
for latitude_longtitude in latitude_longtitude:
    city = citipy.nearest_city(latitude_longtitude[0], latitude_longtitude[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={uom}&q="

# Define an empty list to fetch the weather data for each city
cities_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | orenburg
# Processing Record 2 of Set 1 | tonkino
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | margaret river
# Processing Record 5 of Set 1 | juegang
# Processing Record 6 of Set 1 | iskateley
# Processing Record 7 of Set 1 | aasiaat
# Processing Record 8 of Set 1 | jalalpur jattan
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | puerto natales
# Processing Record 11 of Set 1 | pailon
# Processing Record 12 of Set 1 | utrik
# Processing Record 13 of Set 1 | qusmuryn
# Processing Record 14 of Set 1 | dicle
# Processing Record 15 of Set 1 | mount pearl
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | vorgashor
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | hobyo
# Processing Record 21 of Set 1 | ankazoabo
# Processing Record 22 of Set 1 | mugia
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | enewetak
# Processing Record 25 of Set 1 | concepcion
# Processing Record 26 of Set 1 | guapo
# Processing Record 27 of Set 1 | rikaze
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | san luis de la loma
# Processing Record 31 of Set 1 | vozhega
# Processing Record 32 of Set 1 | hawaiian paradise park
# Processing Record 33 of Set 1 | oroqen zizhiqi
# Processing Record 34 of Set 1 | juan griego
# Processing Record 35 of Set 1 | anadyr
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | ghanzi
# Processing Record 38 of Set 1 | kristiansund
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | rongelap
# Processing Record 41 of Set 1 | puerto baquerizo moreno
# Processing Record 42 of Set 1 | savsat
# Processing Record 43 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | laojunmiao
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | lyskovo
# Processing Record 48 of Set 1 | kapa'a
# Processing Record 49 of Set 1 | guerrero negro
# Processing Record 50 of Set 1 | wailua homesteads
# Processing Record 0 of Set 2 | richlands
# Processing Record 1 of Set 2 | bayji
# Processing Record 2 of Set 2 | greymouth
# Processing Record 3 of Set 2 | happy valley-goose bay
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | plastun
# Processing Record 6 of Set 2 | port lincoln
# Processing Record 7 of Set 2 | hamilton
# Processing Record 8 of Set 2 | roosevelt
# Processing Record 9 of Set 2 | firuzabad
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | huarmey
# Processing Record 13 of Set 2 | stanley
# Processing Record 14 of Set 2 | broome
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | sainte-adresse
# Processing Record 17 of Set 2 | kolonia
# Processing Record 18 of Set 2 | gereida
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | vangaindrano
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | uige
# Processing Record 23 of Set 2 | port mathurin
# Processing Record 24 of Set 2 | tsiombe
# Processing Record 25 of Set 2 | invercargill
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | quezon
# Processing Record 28 of Set 2 | egilsstadir
# Processing Record 29 of Set 2 | caibarien
# Processing Record 30 of Set 2 | west island
# Processing Record 31 of Set 2 | pangody
# Processing Record 32 of Set 2 | kirakira
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | carauari
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 37 of Set 2 | alofi
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | touros
# Processing Record 40 of Set 2 | olonkinbyen
# Processing Record 41 of Set 2 | akureyri
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | nova vicosa
# Processing Record 45 of Set 2 | tazovsky
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | oodweyne
# Processing Record 0 of Set 3 | kodiak
# Processing Record 1 of Set 3 | flying fish cove
# Processing Record 2 of Set 3 | dunedin
# Processing Record 3 of Set 3 | ulanhot
# Processing Record 4 of Set 3 | kapuskasing
# Processing Record 5 of Set 3 | edinburgh of the seven seas
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | kalmar
# Processing Record 8 of Set 3 | twentynine palms
# Processing Record 9 of Set 3 | lompoc
# Processing Record 10 of Set 3 | isafjordur
# Processing Record 11 of Set 3 | badger
# Processing Record 12 of Set 3 | campo gallo
# Processing Record 13 of Set 3 | mana
# Processing Record 14 of Set 3 | antsiranana
# Processing Record 15 of Set 3 | sinop
# Processing Record 16 of Set 3 | wynyard
# Processing Record 17 of Set 3 | bao loc
# City not found. Skipping...
# Processing Record 18 of Set 3 | gurupi
# Processing Record 19 of Set 3 | luga
# Processing Record 20 of Set 3 | jijiga
# Processing Record 21 of Set 3 | haiku-pauwela
# Processing Record 22 of Set 3 | papatowai
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | itaituba
# Processing Record 26 of Set 3 | kerikeri
# Processing Record 27 of Set 3 | yeosu
# Processing Record 28 of Set 3 | meybod
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | sechura
# Processing Record 31 of Set 3 | black point
# Processing Record 32 of Set 3 | labytnangi
# Processing Record 33 of Set 3 | altdorf
# Processing Record 34 of Set 3 | constantia
# Processing Record 35 of Set 3 | igarka
# Processing Record 36 of Set 3 | fort portal
# Processing Record 37 of Set 3 | vadso
# Processing Record 38 of Set 3 | punta arenas
# Processing Record 39 of Set 3 | swakopmund
# Processing Record 40 of Set 3 | mondragon
# Processing Record 41 of Set 3 | kultali
# City not found. Skipping...
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | yarkovo
# Processing Record 44 of Set 3 | whitehorse
# Processing Record 45 of Set 3 | calvinia
# Processing Record 46 of Set 3 | nuuk
# Processing Record 47 of Set 3 | villamontes
# Processing Record 48 of Set 3 | bardai
# Processing Record 49 of Set 3 | udachny
# Processing Record 0 of Set 4 | pacific grove
# Processing Record 1 of Set 4 | agat village
# Processing Record 2 of Set 4 | pskov
# Processing Record 3 of Set 4 | catio
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | novyy urgal
# Processing Record 6 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 4 | danjiangkou
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | fray luis a. beltran
# Processing Record 10 of Set 4 | caxito
# Processing Record 11 of Set 4 | itambe
# Processing Record 12 of Set 4 | karyes
# Processing Record 13 of Set 4 | behshahr
# Processing Record 14 of Set 4 | bol'sherech'ye
# Processing Record 15 of Set 4 | monster
# Processing Record 16 of Set 4 | uturoa
# Processing Record 17 of Set 4 | saipan
# Processing Record 18 of Set 4 | sao jose da coroa grande
# Processing Record 19 of Set 4 | kingston
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | university city
# Processing Record 22 of Set 4 | orel
# Processing Record 23 of Set 4 | la palma
# Processing Record 24 of Set 4 | huanuco
# Processing Record 25 of Set 4 | kununurra
# Processing Record 26 of Set 4 | island harbour
# Processing Record 27 of Set 4 | al qubbah
# Processing Record 28 of Set 4 | acapulco de juarez
# Processing Record 29 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 30 of Set 4 | rio bueno
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | poso
# Processing Record 33 of Set 4 | turabah
# Processing Record 34 of Set 4 | sandnessjoen
# Processing Record 35 of Set 4 | selfoss
# Processing Record 36 of Set 4 | gornyye klyuchi
# Processing Record 37 of Set 4 | grand falls-windsor
# Processing Record 38 of Set 4 | vorkuta
# Processing Record 39 of Set 4 | malvik
# Processing Record 40 of Set 4 | masterton
# Processing Record 41 of Set 4 | lubang
# Processing Record 42 of Set 4 | hafar al-batin
# Processing Record 43 of Set 4 | ain sukhna
# Processing Record 44 of Set 4 | fengcheng
# Processing Record 45 of Set 4 | muroto-misakicho
# Processing Record 46 of Set 4 | kwang binh
# Processing Record 47 of Set 4 | south valley
# Processing Record 48 of Set 4 | hadibu
# Processing Record 49 of Set 4 | san antonio de pale
# Processing Record 0 of Set 5 | zhangjiakou
# Processing Record 1 of Set 5 | afaahiti
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | vintar
# Processing Record 4 of Set 5 | taoudenni
# Processing Record 5 of Set 5 | port saint john's
# Processing Record 6 of Set 5 | as sulayyil
# Processing Record 7 of Set 5 | mermoz boabab
# Processing Record 8 of Set 5 | katsuren-haebaru
# Processing Record 9 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 10 of Set 5 | susuman
# Processing Record 11 of Set 5 | yerofey pavlovich
# Processing Record 12 of Set 5 | miyaly
# Processing Record 13 of Set 5 | phek
# Processing Record 14 of Set 5 | jackson
# Processing Record 15 of Set 5 | nemuro
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | vom
# Processing Record 18 of Set 5 | qamdo
# Processing Record 19 of Set 5 | vilyuchinsk
# Processing Record 20 of Set 5 | salinas
# Processing Record 21 of Set 5 | sarangani
# Processing Record 22 of Set 5 | keflavik
# Processing Record 23 of Set 5 | mizdah
# Processing Record 24 of Set 5 | gizo
# Processing Record 25 of Set 5 | dawson creek
# Processing Record 26 of Set 5 | kurumkan
# Processing Record 27 of Set 5 | barcelos
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | arkhangel'sk
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | acarau
# Processing Record 32 of Set 5 | yulinshi
# Processing Record 33 of Set 5 | sovetskaya gavan'
# Processing Record 34 of Set 5 | namibe
# Processing Record 35 of Set 5 | port hueneme
# Processing Record 36 of Set 5 | paracale
# Processing Record 37 of Set 5 | trenggalek
# Processing Record 38 of Set 5 | chenaran
# Processing Record 39 of Set 5 | kzyltu
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | namtsy
# Processing Record 42 of Set 5 | partizansk
# Processing Record 43 of Set 5 | weno
# Processing Record 44 of Set 5 | margate
# Processing Record 45 of Set 5 | new norfolk
# Processing Record 46 of Set 5 | lamu
# Processing Record 47 of Set 5 | rondonopolis
# Processing Record 48 of Set 5 | santa ines
# Processing Record 49 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 6 | arsk
# Processing Record 1 of Set 6 | lashio
# Processing Record 2 of Set 6 | alvaraes
# Processing Record 3 of Set 6 | choyr
# Processing Record 4 of Set 6 | viedma
# Processing Record 5 of Set 6 | vilyuysk
# Processing Record 6 of Set 6 | doaba
# Processing Record 7 of Set 6 | utete
# Processing Record 8 of Set 6 | hasaki
# Processing Record 9 of Set 6 | coahuayana de hidalgo
# Processing Record 10 of Set 6 | crane
# Processing Record 11 of Set 6 | uzgen
# Processing Record 12 of Set 6 | chonchi
# Processing Record 13 of Set 6 | pemba
# Processing Record 14 of Set 6 | lalibela
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | nar'yan-mar
# Processing Record 17 of Set 6 | auki
# Processing Record 18 of Set 6 | aleg
# Processing Record 19 of Set 6 | smolensk
# Processing Record 20 of Set 6 | carbonear
# Processing Record 21 of Set 6 | twon-brass
# Processing Record 22 of Set 6 | tabou
# Processing Record 23 of Set 6 | ust-nera
# Processing Record 24 of Set 6 | kendari
# Processing Record 25 of Set 6 | taltal
# Processing Record 26 of Set 6 | el alto
# Processing Record 27 of Set 6 | arambagh
# Processing Record 28 of Set 6 | berezovo
# Processing Record 29 of Set 6 | lake city
# Processing Record 30 of Set 6 | tadine
# Processing Record 31 of Set 6 | sorso
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | benghazi
# Processing Record 34 of Set 6 | singaraja
# Processing Record 35 of Set 6 | bafia
# Processing Record 36 of Set 6 | nova sintra
# Processing Record 37 of Set 6 | wawarsing
# Processing Record 38 of Set 6 | saldus
# Processing Record 39 of Set 6 | college
# Processing Record 40 of Set 6 | la sarre
# Processing Record 41 of Set 6 | lampasas
# Processing Record 42 of Set 6 | coquimbo
# Processing Record 43 of Set 6 | minas de marcona
# Processing Record 44 of Set 6 | laguna
# Processing Record 45 of Set 6 | nuku'alofa
# Processing Record 46 of Set 6 | mananara
# Processing Record 47 of Set 6 | kavaratti
# Processing Record 48 of Set 6 | sona
# Processing Record 49 of Set 6 | zag
# Processing Record 0 of Set 7 | sanghar
# Processing Record 1 of Set 7 | praya
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | lagunas
# Processing Record 4 of Set 7 | newman
# Processing Record 5 of Set 7 | chernigovka
# Processing Record 6 of Set 7 | bengkulu
# Processing Record 7 of Set 7 | ulaangom
# Processing Record 8 of Set 7 | borgo san lorenzo
# Processing Record 9 of Set 7 | pante makasar
# City not found. Skipping...
# Processing Record 10 of Set 7 | wellington
# Processing Record 11 of Set 7 | kansanshi
# Processing Record 12 of Set 7 | loon
# Processing Record 13 of Set 7 | labrador city
# Processing Record 14 of Set 7 | st. john's
# Processing Record 15 of Set 7 | khilchipur
# Processing Record 16 of Set 7 | dudinka
# Processing Record 17 of Set 7 | belozersk
# Processing Record 18 of Set 7 | san felipe
# Processing Record 19 of Set 7 | saldanha
# Processing Record 20 of Set 7 | klyuchi
# Processing Record 21 of Set 7 | rawlins
# Processing Record 22 of Set 7 | atafu village
# Processing Record 23 of Set 7 | kaa-khem
# Processing Record 24 of Set 7 | kourou
# Processing Record 25 of Set 7 | kudahuvadhoo
# Processing Record 26 of Set 7 | sao joao do paraiso
# Processing Record 27 of Set 7 | leua
# Processing Record 28 of Set 7 | tucuma
# Processing Record 29 of Set 7 | zalingei
# Processing Record 30 of Set 7 | kanazawa
# Processing Record 31 of Set 7 | acajutla
# Processing Record 32 of Set 7 | okha
# Processing Record 33 of Set 7 | tome
# Processing Record 34 of Set 7 | beichengqu
# Processing Record 35 of Set 7 | greater sudbury
# Processing Record 36 of Set 7 | kismayo
# Processing Record 37 of Set 7 | brisas de zicatela
# Processing Record 38 of Set 7 | daru
# Processing Record 39 of Set 7 | capelinha
# Processing Record 40 of Set 7 | aldan
# Processing Record 41 of Set 7 | bo phloi
# Processing Record 42 of Set 7 | los frentones
# Processing Record 43 of Set 7 | queenstown
# Processing Record 44 of Set 7 | arkalyk
# Processing Record 45 of Set 7 | dolinsk
# Processing Record 46 of Set 7 | chifeng
# Processing Record 47 of Set 7 | paita
# Processing Record 48 of Set 7 | liberal
# Processing Record 49 of Set 7 | basoko
# Processing Record 0 of Set 8 | chulym
# Processing Record 1 of Set 8 | lerwick
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | kabare
# Processing Record 4 of Set 8 | aral
# Processing Record 5 of Set 8 | howard springs
# Processing Record 6 of Set 8 | san juan de miraflores
# Processing Record 7 of Set 8 | sosnovo-ozerskoye
# Processing Record 8 of Set 8 | qal'at bishah
# City not found. Skipping...
# Processing Record 9 of Set 8 | madras
# Processing Record 10 of Set 8 | foindu
# Processing Record 11 of Set 8 | cockburn town
# Processing Record 12 of Set 8 | stiens
# Processing Record 13 of Set 8 | zaozersk
# Processing Record 14 of Set 8 | alpine
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | colchani
# Processing Record 17 of Set 8 | polyarnyy
# Processing Record 18 of Set 8 | dongola
# Processing Record 19 of Set 8 | smithers
# Processing Record 20 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 8 | divnomorskoye
# Processing Record 22 of Set 8 | lata
# Processing Record 23 of Set 8 | biguglia
# Processing Record 24 of Set 8 | tocopilla
# Processing Record 25 of Set 8 | antofagasta
# Processing Record 26 of Set 8 | raton
# Processing Record 27 of Set 8 | leninsk
# Processing Record 28 of Set 8 | plattsburgh
# Processing Record 29 of Set 8 | puerto armuelles
# Processing Record 30 of Set 8 | longgang
# Processing Record 31 of Set 8 | along
# Processing Record 32 of Set 8 | avallon
# Processing Record 33 of Set 8 | mount gambier
# Processing Record 34 of Set 8 | taroudant
# Processing Record 35 of Set 8 | salinopolis
# Processing Record 36 of Set 8 | oranjemund
# Processing Record 37 of Set 8 | mejit
# Processing Record 38 of Set 8 | orosei
# Processing Record 39 of Set 8 | swift current
# Processing Record 40 of Set 8 | la passe
# Processing Record 41 of Set 8 | jeddah
# Processing Record 42 of Set 8 | codrington
# Processing Record 43 of Set 8 | qaqortoq
# Processing Record 44 of Set 8 | aoulef
# Processing Record 45 of Set 8 | baiti
# Processing Record 46 of Set 8 | conception bay south
# Processing Record 47 of Set 8 | terme
# Processing Record 48 of Set 8 | tofol
# Processing Record 49 of Set 8 | sinaloa de leyva
# Processing Record 0 of Set 9 | sao tome
# Processing Record 1 of Set 9 | kayangel
# Processing Record 2 of Set 9 | cuatro cienegas de carranza
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 5 of Set 9 | piedecuesta
# Processing Record 6 of Set 9 | beri khas
# Processing Record 7 of Set 9 | tolanaro
# Processing Record 8 of Set 9 | sinabang
# Processing Record 9 of Set 9 | sotkamo
# Processing Record 10 of Set 9 | port douglas
# Processing Record 11 of Set 9 | inverloch
# Processing Record 12 of Set 9 | winnemucca
# Processing Record 13 of Set 9 | alpena
# Processing Record 14 of Set 9 | luchegorsk
# Processing Record 15 of Set 9 | riberalta
# Processing Record 16 of Set 9 | el granada
# Processing Record 17 of Set 9 | menongue
# Processing Record 18 of Set 9 | necochea
# Processing Record 19 of Set 9 | paradera
# City not found. Skipping...
# Processing Record 20 of Set 9 | westhill
# Processing Record 21 of Set 9 | patong
# Processing Record 22 of Set 9 | aykhal
# Processing Record 23 of Set 9 | laer
# Processing Record 24 of Set 9 | gaiman
# Processing Record 25 of Set 9 | molalla
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | calabozo
# Processing Record 28 of Set 9 | ta`u
# Processing Record 29 of Set 9 | pariaman
# Processing Record 30 of Set 9 | kuchaiburi
# Processing Record 31 of Set 9 | sikonge
# Processing Record 32 of Set 9 | bonthe
# Processing Record 33 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 9 | colonia
# Processing Record 35 of Set 9 | jayapura
# Processing Record 36 of Set 9 | quiberon
# Processing Record 37 of Set 9 | kloulklubed
# Processing Record 38 of Set 9 | atar
# Processing Record 39 of Set 9 | catemaco
# Processing Record 40 of Set 9 | tazacorte
# Processing Record 41 of Set 9 | pokhara
# Processing Record 42 of Set 9 | zaidpur
# Processing Record 43 of Set 9 | sol'-iletsk
# Processing Record 44 of Set 9 | el kef
# Processing Record 45 of Set 9 | mont-dore
# Processing Record 46 of Set 9 | markala
# Processing Record 47 of Set 9 | cruzeiro do sul
# Processing Record 48 of Set 9 | atherton
# Processing Record 49 of Set 9 | wenchang
# Processing Record 0 of Set 10 | al kharijah
# Processing Record 1 of Set 10 | lomza
# Processing Record 2 of Set 10 | mawu
# Processing Record 3 of Set 10 | caras
# Processing Record 4 of Set 10 | remire-montjoly
# Processing Record 5 of Set 10 | yuzhno-kurilsk
# Processing Record 6 of Set 10 | northam
# Processing Record 7 of Set 10 | kupang
# Processing Record 8 of Set 10 | poxoreo
# Processing Record 9 of Set 10 | porto novo
# Processing Record 10 of Set 10 | usinsk
# Processing Record 11 of Set 10 | kindu
# Processing Record 12 of Set 10 | fonte boa
# Processing Record 13 of Set 10 | turpan
# Processing Record 14 of Set 10 | kiunga
# Processing Record 15 of Set 10 | aginskoye
# Processing Record 16 of Set 10 | antalaha
# Processing Record 17 of Set 10 | berberati
# Processing Record 18 of Set 10 | tateyama
# Processing Record 19 of Set 10 | miramichi
# Processing Record 20 of Set 10 | ancud
# Processing Record 21 of Set 10 | zholymbet
# Processing Record 22 of Set 10 | waiuku
# Processing Record 23 of Set 10 | yaren
# Processing Record 24 of Set 10 | holly springs
# Processing Record 25 of Set 10 | tinajo
# Processing Record 26 of Set 10 | trairi
# Processing Record 27 of Set 10 | vuktyl
# Processing Record 28 of Set 10 | palafrugell
# Processing Record 29 of Set 10 | isola di capo rizzuto
# Processing Record 30 of Set 10 | krupki
# Processing Record 31 of Set 10 | ar raqqah
# Processing Record 32 of Set 10 | saida
# Processing Record 33 of Set 10 | pematangsiantar
# Processing Record 34 of Set 10 | harstad
# Processing Record 35 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 10 | lubango
# Processing Record 37 of Set 10 | hailin
# Processing Record 38 of Set 10 | slave lake
# Processing Record 39 of Set 10 | tyukhtet
# Processing Record 40 of Set 10 | nizhnesortymskiy
# Processing Record 41 of Set 10 | fale old settlement
# Processing Record 42 of Set 10 | brookings
# Processing Record 43 of Set 10 | arica
# Processing Record 44 of Set 10 | broken hill
# Processing Record 45 of Set 10 | gaspra
# Processing Record 46 of Set 10 | morehead city
# Processing Record 47 of Set 10 | kone
# Processing Record 48 of Set 10 | hanzhong
# Processing Record 49 of Set 10 | lihue
# Processing Record 0 of Set 11 | arteche
# Processing Record 1 of Set 11 | beloretsk
# Processing Record 2 of Set 11 | altus
# Processing Record 3 of Set 11 | zhuanghe
# Processing Record 4 of Set 11 | suonenjoki
# Processing Record 5 of Set 11 | okhotsk
# Processing Record 6 of Set 11 | hohhot
# Processing Record 7 of Set 11 | pamanukan
# Processing Record 8 of Set 11 | richards bay
# Processing Record 9 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 11 | miles city
# Processing Record 11 of Set 11 | tanjung pandan
# Processing Record 12 of Set 11 | koumra
# Processing Record 13 of Set 11 | faya-largeau
# Processing Record 14 of Set 11 | prince george
# Processing Record 15 of Set 11 | ribeira brava
# Processing Record 16 of Set 11 | porbandar
# Processing Record 17 of Set 11 | dyurtyuli
# Processing Record 18 of Set 11 | makokou
# Processing Record 19 of Set 11 | ndele
# Processing Record 20 of Set 11 | lazaro cardenas
# Processing Record 21 of Set 11 | lishui
# Processing Record 22 of Set 11 | nishinoomote
# Processing Record 23 of Set 11 | el calafate
# Processing Record 24 of Set 11 | sengkang
# Processing Record 25 of Set 11 | nagqu
# Processing Record 26 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 11 | zeya
# Processing Record 28 of Set 11 | ust'-kulom
# Processing Record 29 of Set 11 | outapi
# City not found. Skipping...
# Processing Record 30 of Set 11 | deyang
# Processing Record 31 of Set 11 | abepura
# Processing Record 32 of Set 11 | rio turbio
# City not found. Skipping...
# Processing Record 33 of Set 11 | choibalsan
# Processing Record 34 of Set 11 | rovinj
# Processing Record 35 of Set 11 | pangoa
# Processing Record 36 of Set 11 | tralee
# Processing Record 37 of Set 11 | lyudinovo
# Processing Record 38 of Set 11 | baud
# Processing Record 39 of Set 11 | opuwo
# Processing Record 40 of Set 11 | tamanrasset
# Processing Record 41 of Set 11 | kailua-kona
# Processing Record 42 of Set 11 | peddapalli
# Processing Record 43 of Set 11 | formosa do rio preto
# Processing Record 44 of Set 11 | cole harbour
# Processing Record 45 of Set 11 | sisimiut
# Processing Record 46 of Set 11 | uba
# Processing Record 47 of Set 11 | shengli
# Processing Record 48 of Set 11 | iskushuban
# Processing Record 49 of Set 11 | ad dilam
# Processing Record 0 of Set 12 | fort bragg
# Processing Record 1 of Set 12 | santa elena de uairen
# Processing Record 2 of Set 12 | achinsk
# Processing Record 3 of Set 12 | kolosovka
# Processing Record 4 of Set 12 | mangrol
# Processing Record 5 of Set 12 | griffith
# Processing Record 6 of Set 12 | turan
# Processing Record 7 of Set 12 | great bend
# Processing Record 8 of Set 12 | moroto
# Processing Record 9 of Set 12 | melfi
# Processing Record 10 of Set 12 | raja
# Processing Record 11 of Set 12 | puerto escondido
# Processing Record 12 of Set 12 | urucui
# Processing Record 13 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 14 of Set 12 | markaz-e hukumat-e darweshan
# Processing Record 15 of Set 12 | manokwari
# Processing Record 16 of Set 12 | fort st. john
# Processing Record 17 of Set 12 | victoria
# Processing Record 18 of Set 12 | tashla
# Processing Record 19 of Set 12 | bishkul
# Processing Record 20 of Set 12 | kidal
# Processing Record 21 of Set 12 | jining
# Processing Record 22 of Set 12 | lycksele
# Processing Record 23 of Set 12 | santa maria
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | chui
# Processing Record 26 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 27 of Set 12 | guantanamo
# Processing Record 28 of Set 12 | argo
# Processing Record 29 of Set 12 | at taj
# Processing Record 30 of Set 12 | gadzhiyevo
# Processing Record 31 of Set 12 | impfondo
# Processing Record 32 of Set 12 | altamirano
# Processing Record 33 of Set 12 | yeppoon
# Processing Record 34 of Set 12 | betio village
# Processing Record 35 of Set 12 | ulladulla
# Processing Record 36 of Set 12 | amatitan
# Processing Record 37 of Set 12 | belem de sao francisco
# Processing Record 38 of Set 12 | thunder bay
# Processing Record 39 of Set 12 | forster
# Processing Record 40 of Set 12 | khandyga
# Processing Record 41 of Set 12 | kishtwar
# Processing Record 42 of Set 12 | zhosaly
# Processing Record 43 of Set 12 | port hedland
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | lobujya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
cities_data_df = pd.DataFrame(city_data)

# Show Record Count
cities_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
cities_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
# Export the City_Data into a csv
cities_data_df.to_csv("../WeatherPy/Output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../WeatherPy/Output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#          City_ID.1         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                0         faya  18.3851   42.4509     22.06        35
# 1                1      farsund  58.0948    6.8047     13.30       100
# 2                2  new norfolk -42.7826  147.0587     11.72        58
# 3                3    jamestown  42.0970  -79.2353      5.77        77
# 4                4      lanzhou  36.0564  103.7922     14.53        48
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                21        2.60      SA  1666108228
# 1                 0        7.65      NO  1666108228
# 2                12        1.34      AU  1666108230
# 3               100        9.77      US  1666107934
# 4                59        1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Created a function to reproduce the scatter plots
def build_scatter(x,y):
    plt.scatter(cities_data_df[x], cities_data_df[y], c="red", marker="X", edgecolor="black", linewidths=0.5)
    plt.tight_layout()
    plt.grid()

# %%
# Build the scatter plots for latitude vs. cloudiness
build_scatter("Lat","Wind Speed")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs Wind Speed ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")

# Save the figure
plt.savefig("Output/Fig4.png", bbox_inches="tight")


# Show plot
plt.show()

# %%
# Created a function to reproduce the scatter plots
def build_scatter(x,y):
    plt.scatter(cities_data_df[x], cities_data_df[y], c="red", marker="X", edgecolor="black", linewidths=0.5)
    plt.tight_layout()
    plt.grid()

# %%
# Build the scatter plots for latitude vs. humidity
build_scatter("Lat", "Cloudiness")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({pd.to_datetime(cities_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")

# Save the figure
plt.savefig("Output/Fig3.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
build_scatter("Lat", "Humidity")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")

# Save the figure
plt.savefig("Output/Fig2.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
build_scatter("Lat", "Cloudiness")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")

# Save the figure
plt.savefig("Output/Fig3.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
build_scatter("Lat","Wind Speed")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs Wind Speed ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")

# Save the figure
plt.savefig("Output/Fig4.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linregress_plot(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress = x * slope + intercept
    line_eq = (f"y = {round(slope,2)}x + {round(intercept,2)}")
    print(f"The r-value is: {rvalue}")
    plt.scatter(x, y, c="blue", marker="X", edgecolor="black", linewidths=0.5)
    plt.plot(x,regress,"r")
    plt.annotate(line_eq,(x.min(),y.min()),color="r",fontsize=12)
    plt.tight_layout()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#          City_ID.1       City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                0       faya  18.3851   42.4509     22.06        35
# 1                1    farsund  58.0948    6.8047     13.30       100
# 3                3  jamestown  42.0970  -79.2353      5.77        77
# 4                4    lanzhou  36.0564  103.7922     14.53        48
# 6                6     albany  42.6001  -73.9662     10.36        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                21        2.60      SA  1666108228
# 1                 0        7.65      NO  1666108228
# 3               100        9.77      US  1666107934
# 4                59        1.20      CN  1666108230
# 6                29        2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#          City_ID.1          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                2   new norfolk -42.7826  147.0587     11.72        58
# 5                5       ushuaia -54.8000  -68.3000      8.81        81
# 7                7     carnarvon -24.8667  113.6333     20.02        76
# 9                9  saint-pierre -21.3393   55.4781     22.82        68
# 10              10      colorado -22.8375  -51.9731     20.36        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                12        1.34      AU  1666108230
# 5                75        3.09      AR  1666108231
# 7                 0        7.46      AU  1666108232
# 9                 0        5.14      RE  1666108236
# 10               96        4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (c)")
plt.show()
# Out:
# The r-value is: -0.8462548186825364

# %%
# Linear regression on Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (c)")
plt.show()
# Out:
# The r-value is: 0.6419546065421801

# %% [markdown]
# **Discussion about the linear relationship:**  With an 'r-value' of -0.7 and 0.7, there's a strong correlation between the distance from the equator and the Max Temperature
#     - The northern hemisphere has a strong negative correlation
#     - The southern hemisphere has a strong positive correlation

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
# Out:
# The r-value is: 0.2385317912939407

# %%
# Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
# Out:
# The r-value is: 0.016759316950056818

# %% [markdown]
# **Discussion about the linear relationship:** - Although there's little correlation between Latitude and Humidity, you can clearly see within the scatter plots that for both the Northern and Southern Hemisphere, city's located closest to the equator have Humidity levels > 60%.
# - It would be interesting to look at the city correlation of -10 to 10 latitude degrees from the equator and the Humidity to see if a stronger correlation exists without the outliers of further latitudes affecting the result.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
# Out:
# The r-value is: 0.155004893876971

# %%
# Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
# Out:
# The r-value is: 0.14341322916643243

# %% [markdown]
# **Discussion about the linear relationship:**  There's very little correlation between Cloudiness and City's Latitude.
# - The scatter plots show that cities in the northern hemisphere have much more cloud coverage above 60% than that of the southern hemisphere cities.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.show()
# Out:
# The r-value is: 0.17434667290903338

# %%
# Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])

# Additional plot titles
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.show()
# Out:
# The r-value is: -0.24947753546264592

# %% [markdown]
# **Discussion about the linear relationship:** Very little correlation between Wind Speed and City Latitude for both Northern and Southern Hemisphere Cities.
